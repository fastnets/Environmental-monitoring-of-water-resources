# %%
import pandas as pd
df = pd.read_csv('data.csv', sep=';', dtype={'Сектора деятельности': str})
df.head(10)
# Out:
#                  Регион   Год  \
# 0  Российская Федерация  2013
# 1  Российская Федерация  2014
# 2  Российская Федерация  2014
# 3  Российская Федерация  2014
# 4  Российская Федерация  2014
# 5  Российская Федерация  2014
# 6  Российская Федерация  2014
# 7  Российская Федерация  2014
# 8  Российская Федерация  2014
# 9  Российская Федерация  2014
#
#                                             Параметр  \
# 0  Введено в действие установок для улавливания и...
# 1                        Охрана атмосферного воздуха
# 2                        Охрана атмосферного воздуха
# 3                        Охрана атмосферного воздуха
# 4                        Охрана атмосферного воздуха
# 5                        Охрана атмосферного воздуха
# 6                        Охрана атмосферного воздуха
# 7                        Охрана атмосферного воздуха
# 8                        Охрана атмосферного воздуха
# 9                        Охрана атмосферного воздуха
#
# ...

# %% [markdown]
# # Колонки с небольшим кол-вом значений (имеют какой-то вес для обучения)

# %%
df.iloc[:, 5].unique()
# Out:
# array(['Бюджет субъектов РФ и местных бюджетов', 'Федеральный бюджет',
#        'Экологические фонды', 'Собственные средства организаций', 'Всего',
#        'Бюджеты субъектов Российской Федерации', nan], dtype=object)

# %%
df.iloc[:, 3].unique()
# Out:
# array(['Охрана атмосферного воздуха и проблемы изменения климата',
#        'Очистка сточных вод',
#        'Защита и реабилитация почвы, подземных и поверхностных вод', nan,
#        'Сохранение биоразнообразия и среды обитания',
#        'Обращение с отходами'], dtype=object)

# %%
df.iloc[:, 1].unique()
# Out:
# array([2013, 2014, 2016, 2015, 2012, 2009, 2010, 2011, 2017, 2018, 2019,
#        1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001,
#        2002, 2003, 2004, 2005, 2006, 2007, 2008], dtype=int64)

# %% [markdown]
# ## Не совсем понял что в них находится

# %%
df.iloc[:, 6].unique()
# Out:
# array(['Всего', 'Государственный сектор', nan], dtype=object)

# %%
df.iloc[:, 7].unique()
# Out:
# array(['2106', '0', '37091', ..., '0,134', '0,24', '0,802'], dtype=object)

# %% [markdown]
# ## Колонки с большим количеством значений

# %%
df.iloc[:, 4].unique()
# Out:
# array(['ОКВЭД_01_ОКВЭД_02',
#        'Растениеводство и животноводство, охота и предоставление соответствующих услуг в этих областях',
#        'Обрабатывающие производства',
#        'Производство прочей неметаллической минеральной продукции',
#        'ОКВЭД_24_ОКВЭД_25', 'Производство металлургическое',
#        'Литье чугуна',
#        'Производство основных драгоценных металлов и прочих цветных металлов, производство ядерного топлива',
#        'Производство готовых металлических изделий, кроме машин и оборудования',
#        'ОКВЭД_28.23_ОКВЭД_26.2_ОКВЭД_27_ОКВЭД_26_ОКВЭД_32',
#        'ОКВЭД_29_ОКВЭД_30', 'ОКВЭД_35_ОКВЭД_36', 'Строительство зданий',
#        'ОКВЭД_49_ОКВЭД_50_ОКВЭД_51_ОКВЭД_52_ОКВЭД_53', 'Всего',
#        'Другие виды деятельности (не перечисленные выше)',
#        'Обеспечение электрической энергией, газом и паром; кондиционирование воздуха',
#        'Производство, передача и распределение электроэнергии',
# ...

# %%
df.iloc[:, 2].unique()
# Out:
# array(['Введено в действие установок для улавливания и обезвреживания вредных веществ из отходящих газов',
#        'Охрана атмосферного воздуха',
#        'Охрана и рациональное использование водных ресурсов',
#        'Охрана и рациональное использование земель',
#        'Охрана окружающей среды и рациональное использование природных ресурсов',
#        'Новое строительство за счет всех источников финансирования',
#        'Береговые сооружения',
#        'Береговые станции очистки балластных и льяльных /подсланевых/ вод',
#        'Валы', 'Выполаживание склонов, оврагов, промоин',
#        'Другие сооружения для очистки сточных вод',
#        'Защита от затопления и подтопления территорий и объектов',
#        'Организация заповедников и других природоохранных территорий',
#        'Охрана и воспроизводство диких зверей и птиц',
#        'Охрана и воспроизводство рыбных запасов',
#        'Охрана и рациональное использование лесных ресурсов',
# ...

# %%
df.iloc[:, 0].unique()
# Out:
# array(['Российская Федерация', 'Центральный Федеральный округ',
#        'Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'Липецкая область',
#        'Московская область', 'Орловская область', 'Рязанская область',
#        'Смоленская область', 'Тамбовская область', 'Тверская область',
#        'Тульская область', 'Ярославская область', 'г.Москва',
#        'Северо-Западный Федеральный округ', 'Республика Карелия',
#        'Республика Коми', 'Архангельская область', 'Ненецкий авт.округ',
#        'Архангельская область (кроме Ненецкого автономного округа)',
#        'Вологодская область', 'Калининградская область',
#        'Ленинградская область', 'Мурманская область',
#        'Новгородская область', 'Псковская область', 'г.Санкт-Петербург',
#        'Южный федеральный округ (по 2009 год)',
# ...

# %%
print(df.columns)
# Out:
# Index(['field name', 'english description', 'russian description', 'measure',
#        'okei_code', 'format'],
#       dtype='object')

# %% [markdown]
# # Тоже пока не выкупил зачем остальные 2 файла

# %%
import pandas as pd
df = pd.read_csv('meta.csv', encoding='utf-8')
print(df.head(25))
print(df.columns)
# Out:
#            property                                              value
# 0   standardversion                                                NaN
# 1        identifier                                  ANO CPUR/АНО ЦПУР
# 2             title        «Зеленые» инвестиции в Российской Федерации
# 3       description  Сведения об инвестициях в основной капитал, на...
# 4           creator                                     Росстат, ЕМИСС
# 5           created                                                NaN
# 6          modified                                                NaN
# 7           subject                                                NaN
# 8            format                                                csv
# 9        provenance                                                NaN
# 10            valid                                                NaN
# 11    publishername                              Казанцев Кирилл Ильич
# ...

# %%
print(df.head(25))
# Out:
#            property                                              value
# 0   standardversion                                                NaN
# 1        identifier                                  ANO CPUR/АНО ЦПУР
# 2             title        «Зеленые» инвестиции в Российской Федерации
# 3       description  Сведения об инвестициях в основной капитал, на...
# 4           creator                                     Росстат, ЕМИСС
# 5           created                                                NaN
# 6          modified                                                NaN
# 7           subject                                                NaN
# 8            format                                                csv
# 9        provenance                                                NaN
# 10            valid                                                NaN
# 11    publishername                              Казанцев Кирилл Ильич
# ...

# %%
df = pd.read_csv('structure.csv', sep=',')
print(df.head())
print(df.columns)
# Out:
#                                           field name  \
# 0                                             Регион
# 1                                                Год
# 2                                           Параметр
# 3                                               CEPA
# 4  Классификатор видов экономической деятельности...
#
#                                  english description  \
# 0         Name of the Region (subject of federation)
# 1                                               Year
# 2                              Name of the indicator
# 3                   Classification according to CEPA
# 4  Classification according to OKVED (type of act...
#
#                                russian description  measure  okei_code  format
# 0        Наименование региона (субъекта федерации)      NaN        NaN  string
# 1                                              Год      NaN        NaN     int
# 2                              Название индикатора      NaN        NaN  string
# ...
